# %%
import sys
# !{sys.executable} -m pip install pandas numpy matplotlib seaborn scikit-learn weasyprint --quiet
print("Instalacion completa.")
# Out:
# Instalacion completa.
# WARNING: Ignoring invalid distribution -orch (g:\miniforge3\envs\gpu\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (g:\miniforge3\envs\gpu\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (g:\miniforge3\envs\gpu\lib\site-packages)

# %%
import pandas, numpy, matplotlib, seaborn, sklearn, weasyprint
print(f"pandas      : {pandas.__version__}")
print(f"numpy       : {numpy.__version__}")
print(f"matplotlib  : {matplotlib.__version__}")
print(f"seaborn     : {seaborn.__version__}")
print(f"scikit-learn: {sklearn.__version__}")
print(f"weasyprint  : {weasyprint.__version__}")
print("Todo listo!")
# Out:
# pandas      : 2.3.3
# numpy       : 1.26.4
# matplotlib  : 3.10.8
# seaborn     : 0.13.2
# scikit-learn: 1.7.2
# weasyprint  : 68.1
# Todo listo!
